# %%
import pandas as pd

# %%
path=r'D:\PG DS - Machine Learning\E-Books From LMS\Demo Datasets\Lesson 4'
data=pd.read_csv(path+r'\train.csv')

# %%
data=pd.read_csv('D:/PG DS - Machine Learning/E-Books From LMS/Demo Datasets/Lesson 4/train.csv')

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data.head() #to displays the first 5 records
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.head(3) #if you want to display certain number of records
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
data.tail() #displays last 5 record
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
# data.to_csv("test.csv") ---> to save the data in any format

# %%
# if you want to read any other delimiter separated data then??
# data=pd.read_csv(path+r'\train.csv',sep='#')

# %%
pwd()
# Out:
# 'C:\\Users\\Divya J'

# %%
ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 6055-66BA
#
#  Directory of C:\Users\Divya J
#
# 27-04-2022  13:01    <DIR>          .
# 27-04-2022  13:01    <DIR>          ..
# 01-03-2021  09:33               145 .appletviewer
# 01-02-2022  23:08    <DIR>          .cache
# 16-03-2022  15:53    <DIR>          .conda
# 01-02-2022  23:09    <DIR>          .eclipse
# 26-04-2022  22:56    <DIR>          .ipynb_checkpoints
# 15-02-2022  00:37    <DIR>          .ipython
# 15-02-2022  00:52    <DIR>          .jupyter
# 12-03-2022  20:25    <DIR>          .matplotlib
# 05-02-2022  13:29    <DIR>          .p2
# 04-09-2021  12:36               616 .xmaximarc
# 13-03-2022  13:32           350,855 05_Feb_2022 - Titanic Data Analysis updated.ipynb
# 14-04-2022  12:29            88,661 1.Introduction to Python Basics .ipynb
# 17-03-2022  23:20            14,762 13.MACHINE LEARNING.ipynb
# 09-03-2022  10:18         2,985,931 2.Control flow statements in Python.ipynb
# ...

# %%
df=pd.read_csv(path+r'\train.csv',header=None) #when we dont want the column names to  be displayed 
df
# Out:
#               0         1       2   \
# 0    PassengerId  Survived  Pclass
# 1              1         0       3
# 2              2         1       1
# 3              3         1       3
# 4              4         1       1
# ..           ...       ...     ...
# 887          887         0       2
# 888          888         1       1
# 889          889         0       3
# 890          890         1       1
# 891          891         0       3
#
#                                                     3       4    5      6   \
# 0                                                 Name     Sex  Age  SibSp
# 1                              Braund, Mr. Owen Harris    male   22      1
# 2    Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 3                               Heikkinen, Miss. Laina  female   26      0
# 4         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# ..                                                 ...     ...  ...    ...
# ...

# %%
#when we  want to give our own column names
df=pd.read_csv(path+r'\train.csv',header=None,names=['a','b','c','d','e','f','g','h','i','j','k','l'])
df
# Out:
#                a         b       c  \
# 0    PassengerId  Survived  Pclass
# 1              1         0       3
# 2              2         1       1
# 3              3         1       3
# 4              4         1       1
# ..           ...       ...     ...
# 887          887         0       2
# 888          888         1       1
# 889          889         0       3
# 890          890         1       1
# 891          891         0       3
#
#                                                      d       e    f      g  \
# 0                                                 Name     Sex  Age  SibSp
# 1                              Braund, Mr. Owen Harris    male   22      1
# 2    Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 3                               Heikkinen, Miss. Laina  female   26      0
# 4         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# ..                                                 ...     ...  ...    ...
# ...

# %%
df=pd.read_csv(path+r'\train.csv',header=None,names=['a','b','c','d','e','f','g','h','i','j','k','l'],skiprows=[0,2,3],
              na_values=[1])
df.head()
# Out:
#      a    b    c                                             d       e     f  \
# 0  NaN  0.0  3.0                       Braund, Mr. Owen Harris    male  22.0
# 1  4.0  NaN  NaN  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 2  5.0  0.0  3.0                      Allen, Mr. William Henry    male  35.0
# 3  6.0  0.0  3.0                              Moran, Mr. James    male   NaN
# 4  7.0  0.0  NaN                       McCarthy, Mr. Timothy J    male  54.0
#
#      g    h          i        j     k  l
# 0  NaN  0.0  A/5 21171   7.2500   NaN  S
# 1  NaN  0.0     113803  53.1000  C123  S
# 2  0.0  0.0     373450   8.0500   NaN  S
# 3  0.0  0.0     330877   8.4583   NaN  Q
# 4  0.0  0.0      17463  51.8625   E46  S

# %%
df=pd.read_csv(path+r'\train.csv',header=None,names=['a','b','c','d','e','f','g','h','i','j','k','l'],
              na_values=[1,'S','male']) #na_values is used to make some of the values as nan
df.head()
# Out:
#              a         b       c  \
# 0  PassengerId  Survived  Pclass
# 1          NaN         0       3
# 2            2       NaN     NaN
# 3            3       NaN       3
# 4            4       NaN     NaN
#
#                                                    d       e    f      g  \
# 0                                               Name     Sex  Age  SibSp
# 1                            Braund, Mr. Owen Harris     NaN   22    NaN
# 2  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38    NaN
# 3                             Heikkinen, Miss. Laina  female   26      0
# 4       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35    NaN
#
#        h                 i        j      k         l
# 0  Parch            Ticket     Fare  Cabin  Embarked
# 1      0         A/5 21171     7.25    NaN       NaN
# 2      0          PC 17599  71.2833    C85         C
# 3      0  STON/O2. 3101282    7.925    NaN       NaN
# 4      0            113803     53.1   C123       NaN

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
data.describe(percentiles=[0.25,0.5,0.75,0.9],include='all')
# Out:
#         PassengerId    Survived      Pclass                     Name   Sex  \
# count    891.000000  891.000000  891.000000                      891   891
# unique          NaN         NaN         NaN                      891     2
# top             NaN         NaN         NaN  Braund, Mr. Owen Harris  male
# freq            NaN         NaN         NaN                        1   577
# mean     446.000000    0.383838    2.308642                      NaN   NaN
# std      257.353842    0.486592    0.836071                      NaN   NaN
# min        1.000000    0.000000    1.000000                      NaN   NaN
# 25%      223.500000    0.000000    2.000000                      NaN   NaN
# 50%      446.000000    0.000000    3.000000                      NaN   NaN
# 75%      668.500000    1.000000    3.000000                      NaN   NaN
# 90%      802.000000    1.000000    3.000000                      NaN   NaN
# ...

# %%
data.describe(include=['O'])
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
data.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.dtypes
# Out:
# a    object
# b    object
# c    object
# d    object
# e    object
# f    object
# g    object
# h    object
# i    object
# j    object
# k    object
# l    object
# dtype: object

# %%
df.describe()
# Out:
#                   a    b    c     d       e    f    g    h     i     j  \
# count           891  550  676   892     315  708  683  774   892   892
# unique          891    2    3   892       2   88    7    7   682   249
# top     PassengerId    0    3  Name  female   24    0    0  1601  8.05
# freq              1  549  491     1     314   30  608  678     7    43
#
#                   k    l
# count           205  246
# unique          148    3
# top     C23 C25 C27    C
# freq              4  168

# %%
df.to_csv("result1.csv",index=False,header=False,sep="#",columns=['a','b'])

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
type(data['PassengerId'])
# Out:
# pandas.core.series.Series

# %%
data[['PassengerId']]
# Out:
#      PassengerId
# 0              1
# 1              2
# 2              3
# 3              4
# 4              5
# ..           ...
# 886          887
# 887          888
# 888          889
# 889          890
# 890          891
#
# [891 rows x 1 columns]

# %%
type(data[['PassengerId']])
# Out:
# pandas.core.frame.DataFrame

# %%
data['PassengerId','Survived'] # this gives error
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# D:\DivyaPython\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# D:\DivyaPython\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# D:\DivyaPython\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('PassengerId', 'Survived')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
data[['PassengerId','Survived']] #Extracting particular columns
# Out:
#      PassengerId  Survived
# 0              1         0
# 1              2         1
# 2              3         1
# 3              4         1
# 4              5         0
# ..           ...       ...
# 886          887         0
# 887          888         1
# 888          889         0
# 889          890         1
# 890          891         0
#
# [891 rows x 2 columns]

# %%
df1=pd.read_excel('C:/Users/Divya J/Downloads/sample-excel-master/LUSID Excel - Business Agility - Making Simple Changes Quickly & Easily.xlsx',sheet_name='Add your take on balances')
df1
# Out:
#     Unnamed: 0  Unnamed: 1                                         Unnamed: 2  \
# 0          NaN         NaN                                                NaN
# 1          NaN         NaN                                                NaN
# 2          NaN         NaN                                                NaN
# 3          NaN         NaN                                                NaN
# 4          NaN         NaN                                                NaN
# 5          NaN         NaN                                                NaN
# 6          NaN         NaN                                                NaN
# 7          NaN         NaN                                                NaN
# 8          NaN         NaN                                                NaN
# 9          NaN         NaN                                                NaN
# 10         NaN         NaN                                                NaN
# ...

# %%
df2=pd.read_excel('C:/Users/Divya J/Downloads/sample-excel-master/LUSID Excel - Business Agility - Making Simple Changes Quickly & Easily.xlsx',sheet_name='Create your instrument universe')
df2
# Out:
#     Unnamed: 0  Unnamed: 1 Unnamed: 2  Unnamed: 3    Unnamed: 4 Unnamed: 5  \
# 0          NaN         NaN        NaN         NaN           NaN        NaN
# 1          NaN         NaN        NaN         NaN           NaN        NaN
# 2          NaN         NaN        NaN         NaN           NaN        NaN
# 3          NaN         NaN        NaN         NaN           NaN        NaN
# 4          NaN         NaN        NaN         NaN           NaN        NaN
# ..         ...         ...        ...         ...           ...        ...
# 66         NaN         NaN        NaN         NaN  BBG0000D14P3     Active
# 67         NaN         NaN        NaN         NaN  BBG00FN3B5K8     Active
# 68         NaN         NaN        NaN         NaN  BBG000DQQNJ8     Active
# 69         NaN         NaN        NaN         NaN  BBG000BF6B57     Active
# 70         NaN         NaN        NaN         NaN  BBG000BRVH05     Active
#
# ...

# %%
d1=pd.read_excel(r'C:\Users\Divya J\Documents\Book1.xlsx',sheet_name=0)
d2=pd.read_excel(r'C:\Users\Divya J\Documents\Book1.xlsx',sheet_name=1)
d=pd.concat([d1,d2],axis=1,join='inner')
d
# Out:
#      Name Flag   Name Flag
# 0   Divya   ML  Divya  NLP
# 1   Divya   DL  Divya  NLP
# 2   Divya   ML  Divya  NLP
# 3   Divya   DL  Divya  NLP
# 4   Divya   ML  Divya  NLP
# 5   Sudha   DL  Sudha  NLP
# 6   Sudha   ML  Sudha  NLP
# 7   Sudha   DL  Sudha  NLP
# 8   Sudha   ML  Sudha  NLP
# 9   Sudha   DL  Sudha  NLP
# 10  Sudha   ML  Sudha  NLP

# %%
d1.value_counts().sort_values()
# Out:
# Name   Flag
# Divya  DL      2
#        ML      3
# Sudha  DL      3
#        ML      3
# dtype: int64

# %%
df3=pd.read_html("https://www.basketball-reference.com/players/i/ibakase01.html?utm_source=direct&utm_medium=Share&utm_campaign=ShareTool")
df3
# Out:
# [       Season   Age                                     Tm  \
#  0     2008-09  19.0  Did Not Play (other pro league—Spain)
#  1     2009-10  20.0                                    OKC
#  2     2010-11  21.0                                    OKC
#  3     2011-12  22.0                                    OKC
#  4     2012-13  23.0                                    OKC
#  5     2013-14  24.0                                    OKC
#  6     2014-15  25.0                                    OKC
#  7     2015-16  26.0                                    OKC
#  8     2016-17  27.0                                    TOT
#  9     2016-17  27.0                                    ORL
#  10    2016-17  27.0                                    TOR
#  11    2017-18  28.0                                    TOR
#  12    2018-19  29.0                                    TOR
#  13    2019-20  30.0                                    TOR
#  14    2020-21  31.0                                    LAC
# ...

# %%
type(df3)
# Out:
# list

# %%
len(df3)
# Out:
# 6

# %%
df3[0]
# Out:
#        Season   Age                                     Tm  \
# 0     2008-09  19.0  Did Not Play (other pro league—Spain)
# 1     2009-10  20.0                                    OKC
# 2     2010-11  21.0                                    OKC
# 3     2011-12  22.0                                    OKC
# 4     2012-13  23.0                                    OKC
# 5     2013-14  24.0                                    OKC
# 6     2014-15  25.0                                    OKC
# 7     2015-16  26.0                                    OKC
# 8     2016-17  27.0                                    TOT
# 9     2016-17  27.0                                    ORL
# 10    2016-17  27.0                                    TOR
# 11    2017-18  28.0                                    TOR
# 12    2018-19  29.0                                    TOR
# 13    2019-20  30.0                                    TOR
# 14    2020-21  31.0                                    LAC
# ...

# %%
#df3[3].to_csv("Players_data.csv") #saving it as csv file

# %%
#html_data=pd.read_html("https://www.basketball-reference.com/players/i/ibakase01.html?utm_source=direct&utm_medium=Share&utm_campaign=ShareTool")
#for i in range(len(html_data)):
#    html_data[i].to_csv(f'html_data{i}.csv',index=False)

# %%
data=pd.read_csv('D:/PG DS - Machine Learning/E-Books From LMS/Demo Datasets/Lesson 4/train.csv')
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
s = """{
"Name" : "Divya",
"Phone_num" : 1234567889,
"Languages_known" : ["English","Kannada","Telugu","Tamil","Hindi"]
}
"""

# %%
import json #javascript object notation(JSON)

# %%
s1=json.loads(s) #check whether the data is in json format use online json viewer
s1
# Out:
# {'Name': 'Divya',
#  'Phone_num': 1234567889,
#  'Languages_known': ['English', 'Kannada', 'Telugu', 'Tamil', 'Hindi']}

# %%
pd.DataFrame(s1)
# Out:
#     Name   Phone_num Languages_known
# 0  Divya  1234567889         English
# 1  Divya  1234567889         Kannada
# 2  Divya  1234567889          Telugu
# 3  Divya  1234567889           Tamil
# 4  Divya  1234567889           Hindi

# %%
pd.DataFrame(s1,columns=['Languages_known'])
# Out:
#   Languages_known
# 0         English
# 1         Kannada
# 2          Telugu
# 3           Tamil
# 4           Hindi

# %%
import requests

# %%
res=requests.get('https://api.github.com/repos/pandas-dev/pandas/issues')

# %%
res
# Out:
# <Response [200]>

# %%
js=res.json()
js
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46883',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46883/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46883/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46883/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/46883',
#   'id': 1216892510,
#   'node_id': 'PR_kwDOAA0YD8422cbB',
#   'number': 46883,
#   'title': 'DOC: GH27557 Updates Python support documentation to match NumPy NEP 29',
#   'user': {'login': 'JosephParampathu',
#    'id': 88171669,
#    'node_id': 'MDQ6VXNlcjg4MTcxNjY5',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/88171669?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/JosephParampathu',
#    'html_url': 'https://github.com/JosephParampathu',
# ...

# %%
js[0]
# Out:
# {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46883',
#  'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#  'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46883/labels{/name}',
#  'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46883/comments',
#  'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46883/events',
#  'html_url': 'https://github.com/pandas-dev/pandas/pull/46883',
#  'id': 1216892510,
#  'node_id': 'PR_kwDOAA0YD8422cbB',
#  'number': 46883,
#  'title': 'DOC: GH27557 Updates Python support documentation to match NumPy NEP 29',
#  'user': {'login': 'JosephParampathu',
#   'id': 88171669,
#   'node_id': 'MDQ6VXNlcjg4MTcxNjY5',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/88171669?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/JosephParampathu',
#   'html_url': 'https://github.com/JosephParampathu',
# ...

# %%
js[0]['title']
# Out:
# 'DOC: GH27557 Updates Python support documentation to match NumPy NEP 29'

# %%
for i in range(len(js)):
    print(js[i]['title'])
# Out:
# DOC: GH27557 Updates Python support documentation to match NumPy NEP 29
# ENH: allow preserving one of the indexes when merging two DataFrames
# Backport PR #45247 on branch 1.4.x (PERF: find_stack_level)
# REF: libhashtable.mode support mask
# Merge nonstring columns
# PERF: use C version of np.empty
# BUG: `pd.date_range` not factoring in `nanoseconds` in `freq`
# BUG: pd.read_sql returns wrong columns name for specific query
# BUG: extra row created when calling to_excel for multi-index columns
# BUG: Error when exporting an empty DataFrame with MultiIndex to xlsx file
# BUG: DataFrame.select_dtypes(include='number') includes BooleanDtype columns
# BUG: SettingWithCopyWarning
# ENH: Dataframe constructor and DataFrame.from_records shoudl allow specifying column dtypes
# BUG: groupby.transform with execution engine numba does not work in multiindex case since 1.3
# STYLE replace flake8-rst with something maintained
# BUG: duplicated() returns different results on consecutive runs!
# ...

# %%
for i in range(len(js)):
    print(js[i]['node_id'])

# %%
df4=pd.DataFrame(js)
df4.head()
# Out:
#                                                  url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
# 2  https://api.github.com/repos/pandas-dev/pandas...
# 3  https://api.github.com/repos/pandas-dev/pandas...
# 4  https://api.github.com/repos/pandas-dev/pandas...
#
#                                    repository_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas
# 1  https://api.github.com/repos/pandas-dev/pandas
# 2  https://api.github.com/repos/pandas-dev/pandas
# 3  https://api.github.com/repos/pandas-dev/pandas
# 4  https://api.github.com/repos/pandas-dev/pandas
#
#                                           labels_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
# 2  https://api.github.com/repos/pandas-dev/pandas...
# 3  https://api.github.com/repos/pandas-dev/pandas...
# 4  https://api.github.com/repos/pandas-dev/pandas...
#
# ...

# %%
df4.to_csv('Json_data.csv')

# %%
l=[]
for i in range(len(js)):
    l.append(js[i]['user'])

df5=pd.DataFrame(l)
df5.head()
# Out:
#               login        id               node_id  \
# 0  JosephParampathu  88171669  MDQ6VXNlcjg4MTcxNjY5
# 1        multimeric   5019367  MDQ6VXNlcjUwMTkzNjc=
# 2   meeseeksmachine  39504233  MDQ6VXNlcjM5NTA0MjMz
# 3      jbrockmendel   8078968  MDQ6VXNlcjgwNzg5Njg=
# 4         ericman93   5768348  MDQ6VXNlcjU3NjgzNDg=
#
#                                           avatar_url gravatar_id  \
# 0  https://avatars.githubusercontent.com/u/881716...
# 1  https://avatars.githubusercontent.com/u/501936...
# 2  https://avatars.githubusercontent.com/u/395042...
# 3  https://avatars.githubusercontent.com/u/807896...
# 4  https://avatars.githubusercontent.com/u/576834...
#
#                                              url  \
# 0  https://api.github.com/users/JosephParampathu
# 1        https://api.github.com/users/multimeric
# 2   https://api.github.com/users/meeseeksmachine
# 3      https://api.github.com/users/jbrockmendel
# 4         https://api.github.com/users/ericman93
#
# ...

# %%
#alternate approach
json_data=pd.read_json('https://api.github.com/repos/pandas-dev/pandas/issues')
df6=pd.DataFrame.from_records(json_data['user'])
df6.head()
# Out:
#               login        id               node_id  \
# 0  JosephParampathu  88171669  MDQ6VXNlcjg4MTcxNjY5
# 1        multimeric   5019367  MDQ6VXNlcjUwMTkzNjc=
# 2   meeseeksmachine  39504233  MDQ6VXNlcjM5NTA0MjMz
# 3      jbrockmendel   8078968  MDQ6VXNlcjgwNzg5Njg=
# 4         ericman93   5768348  MDQ6VXNlcjU3NjgzNDg=
#
#                                           avatar_url gravatar_id  \
# 0  https://avatars.githubusercontent.com/u/881716...
# 1  https://avatars.githubusercontent.com/u/501936...
# 2  https://avatars.githubusercontent.com/u/395042...
# 3  https://avatars.githubusercontent.com/u/807896...
# 4  https://avatars.githubusercontent.com/u/576834...
#
#                                              url  \
# 0  https://api.github.com/users/JosephParampathu
# 1        https://api.github.com/users/multimeric
# 2   https://api.github.com/users/meeseeksmachine
# 3      https://api.github.com/users/jbrockmendel
# 4         https://api.github.com/users/ericman93
#
# ...

# %%
form_file=pd.read_csv(r'C:\Users\Divya J\html_data1.csv')

# %%
form_file.to_pickle("my_pickel")

# %%
h5_data=pd.HDFStore('test.h5') #just instance of a file is created here

# %%
h5_data['obj1']=form_file #calling h5_data and creating a new column/instance and storing all the data in form_file
# Out:
# D:\DivyaPython\lib\site-packages\IPython\core\interactiveshell.py:3444: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block1_values] [items->Index(['Season', 'Tm', 'Lg', 'Pos'], dtype='object')]
#
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
h5_data['obj1'] #checking
# Out:
#        Season   Age   Tm   Lg  Pos      G     GS    MP   FG   FGA  ...    FT%  \
# 0     2009-10  20.0  OKC  NBA   PF    6.0    0.0  25.5  3.3   5.8  ...  0.700
# 1     2010-11  21.0  OKC  NBA   PF   17.0   17.0  28.8  3.9   8.5  ...  0.825
# 2     2011-12  22.0  OKC  NBA   PF   20.0   20.0  28.5  4.2   8.0  ...  0.722
# 3     2012-13  23.0  OKC  NBA   PF   11.0   11.0  33.3  5.4  12.3  ...  0.792
# 4     2013-14  24.0  OKC  NBA   PF   17.0   17.0  34.2  5.1   8.6  ...  0.765
# 5     2015-16  26.0  OKC  NBA   PF   18.0   18.0  33.4  4.7   9.1  ...  0.750
# 6     2016-17  27.0  TOR  NBA   PF   10.0   10.0  30.7  6.0  13.0  ...  0.846
# 7     2017-18  28.0  TOR  NBA   PF   10.0    9.0  26.0  3.0   7.2  ...  0.818
# 8     2018-19  29.0  TOR  NBA    C   24.0    0.0  20.8  3.8   8.0  ...  0.762
# 9     2019-20  30.0  TOR  NBA    C   11.0    0.0  22.8  5.7  10.0  ...  1.000
# 10    2020-21  31.0  LAC  NBA    C    2.0    0.0   9.0  1.5   3.0  ...  1.000
# ...

# %%
h5_data.put('obj2',form_file,format='table')

# %%
h5_data.select('obj2',where=['index>=10 and index<=15'])
# Out:
#        Season   Age   Tm   Lg  Pos      G     GS    MP   FG  FGA  ...    FT%  \
# 10    2020-21  31.0  LAC  NBA    C    2.0    0.0   9.0  1.5  3.0  ...  1.000
# 11    2021-22  32.0  MIL  NBA   PF    3.0    0.0   4.0  1.3  3.0  ...  0.500
# 12     Career   NaN  NaN  NBA  NaN  149.0  102.0  27.6  4.4  8.8  ...  0.789
# 13        NaN   NaN  NaN  NaN  NaN    NaN    NaN   NaN  NaN  NaN  ...    NaN
# 14  6 seasons   NaN  OKC  NBA  NaN   89.0   83.0  31.0  4.5  8.8  ...  0.768
# 15  4 seasons   NaN  TOR  NBA  NaN   55.0   19.0  24.0  4.5  9.2  ...  0.824
#
#     ORB  DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# 10  0.5  1.5  2.0  1.0  0.5  1.5  0.5  0.5   5.0
# 11  0.7  2.0  2.7  0.0  0.0  0.0  0.3  0.3   3.0
# 12  1.9  4.6  6.5  0.7  0.4  2.0  0.9  3.0  10.8
# 13  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 14  2.2  4.5  6.7  0.5  0.5  2.5  0.8  3.2  10.9
# 15  1.3  5.1  6.4  1.1  0.3  1.2  1.2  3.0  11.2
#
# [6 rows x 30 columns]

# %%
data=pd.read_csv('D:/PG DS - Machine Learning/E-Books From LMS/Demo Datasets/Lesson 4/train.csv')

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
data.dtypes=='object'
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name            True
# Sex             True
# Age            False
# SibSp          False
# Parch          False
# Ticket          True
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
data.dtypes[data.dtypes=='object']
# Out:
# Name        object
# Sex         object
# Ticket      object
# Cabin       object
# Embarked    object
# dtype: object

# %%
data.dtypes[data.dtypes=='object'].index
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
df1=data[data.dtypes[data.dtypes=='object'].index]#passing the list into dataframe

# %%
df1.describe()
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
data[data.dtypes[data.dtypes=='float64'].index].head()
# Out:
#     Age     Fare
# 0  22.0   7.2500
# 1  38.0  71.2833
# 2  26.0   7.9250
# 3  35.0  53.1000
# 4  35.0   8.0500

# %%
data['Name'] #series is just like a list operation
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
data['Name'][5]
# Out:
# 'Moran, Mr. James'

# %%
data['Name'][0:11:2]
# Out:
# 0                               Braund, Mr. Owen Harris
# 2                                Heikkinen, Miss. Laina
# 4                              Allen, Mr. William Henry
# 6                               McCarthy, Mr. Timothy J
# 8     Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 10                      Sandstrom, Miss. Marguerite Rut
# Name: Name, dtype: object

# %%
sorted(data['Ticket'])
# Out:
# ['110152',
#  '110152',
#  '110152',
#  '110413',
#  '110413',
#  '110413',
#  '110465',
#  '110465',
#  '110564',
#  '110813',
#  '111240',
#  '111320',
#  '111361',
#  '111361',
#  '111369',
#  '111426',
#  '111427',
#  '111428',
#  '112050',
#  '112052',
#  '112053',
#  '112058',
#  '112059',
#  '112277',
#  '112379',
#  '113028',
#  '113043',
#  '113050',
#  '113051',
#  '113055',
#  '113056',
#  '113059',
#  '113501',
#  '113503',
#  '113505',
#  '113505',
#  '113509',
#  '113510',
#  '113514',
#  '113572',
#  '113572',
#  '113760',
#  '113760',
#  '113760',
#  '113760',
#  '113767',
#  '113773',
#  '113776',
#  '113776',
#  '113781',
#  '113781',
#  '113781',
#  '113781',
#  '113783',
#  '113784',
#  '113786',
#  '113787',
#  '113788',
#  '113789',
#  '113789',
#  '113792',
#  '113794',
#  '113796',
#  '113798',
#  '113798',
#  '113800',
#  '113803',
#  '113803',
#  '113804',
#  '113806',
#  '113806',
#  '113807',
#  '11668',
#  '11668',
#  '11751',
#  '11751',
#  '11752',
# ...

# %%
data[['Ticket']][5:15]
# Out:
#        Ticket
# 5      330877
# 6       17463
# 7      349909
# 8      347742
# 9      237736
# 10    PP 9549
# 11     113783
# 12  A/5. 2151
# 13     347082
# 14     350406

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
for i in data.columns:
    print(data[[i]])
# Out:
#      PassengerId
# 0              1
# 1              2
# 2              3
# 3              4
# 4              5
# ..           ...
# 886          887
# 887          888
# 888          889
# 889          890
# 890          891
#
# [891 rows x 1 columns]
#      Survived
# 0           0
# 1           1
# 2           1
# 3           1
# 4           0
# ..        ...
# 886         0
# 887         1
# 888         0
# 889         1
# 890         0
#
# [891 rows x 1 columns]
#      Pclass
# 0         3
# 1         1
# 2         3
# 3         1
# 4         3
# ..      ...
# 886       2
# 887       1
# 888       3
# 889       1
# 890       3
#
# [891 rows x 1 columns]
#                                                   Name
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# ...

# %%
#to add new column
data['Divu']="Reddy"

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data['Divu1']=data['PassengerId']
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
pd.Categorical(data['Cabin'])
# Out:
# [NaN, 'C85', NaN, 'C123', NaN, ..., NaN, 'B42', NaN, 'C148', NaN]
# Length: 891
# Categories (147, object): ['A10', 'A14', 'A16', 'A19', ..., 'F38', 'F4', 'G6', 'T']

# %%
pd.Categorical(data['Sex'])
# Out:
# ['male', 'female', 'female', 'female', 'male', ..., 'male', 'female', 'female', 'male', 'male']
# Length: 891
# Categories (2, object): ['female', 'male']

# %%
pd.Categorical(data['Pclass'])
# Out:
# [3, 1, 3, 1, 3, ..., 2, 1, 3, 1, 3]
# Length: 891
# Categories (3, int64): [1, 2, 3]

# %%
data['Pclass'].unique()
# Out:
# array([3, 1, 2], dtype=int64)

# %%
data['Pclass'].isna()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Pclass, Length: 891, dtype: bool

# %%
a=data['Cabin'][data['Cabin'].isnull()==True]

# %%
a.index
# Out:
# Int64Index([  0,   2,   4,   5,   7,   8,   9,  12,  13,  14,
#             ...
#             878, 880, 881, 882, 883, 884, 885, 886, 888, 890],
#            dtype='int64', length=687)

# %%
print(len(a.index))
# Out:
# 687

# %%
data.iloc[a.index]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 2              3         1       3                    Heikkinen, Miss. Laina
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
data.iloc[[0,2,4,6]]
# Out:
#    PassengerId  Survived  Pclass                      Name     Sex   Age  \
# 0            1         0       3   Braund, Mr. Owen Harris    male  22.0
# 2            3         1       3    Heikkinen, Miss. Laina  female  26.0
# 4            5         0       3  Allen, Mr. William Henry    male  35.0
# 6            7         0       1   McCarthy, Mr. Timothy J    male  54.0
#
#    SibSp  Parch            Ticket     Fare Cabin Embarked   Divu  Divu1
# 0      1      0         A/5 21171   7.2500   NaN        S  Reddy      1
# 2      0      0  STON/O2. 3101282   7.9250   NaN        S  Reddy      3
# 4      0      0            373450   8.0500   NaN        S  Reddy      5
# 6      0      0             17463  51.8625   E46        S  Reddy      7

# %%
data[data['Fare']==max(data['Fare'])]['Name']
# Out:
# 258                      Ward, Miss. Anna
# 679    Cardeza, Mr. Thomas Drake Martinez
# 737                Lesurer, Mr. Gustave J
# Name: Name, dtype: object

# %%
pd.DataFrame(data[data['Fare']==data['Fare'].max()]['Name'])
# Out:
#                                    Name
# 258                    Ward, Miss. Anna
# 679  Cardeza, Mr. Thomas Drake Martinez
# 737              Lesurer, Mr. Gustave J

# %%
data['New_column']=data['PassengerId']+data['Age']

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df=pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv',sep="\t")

# %%
df.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
df.dtypes
# Out:
# order_id               int64
# quantity               int64
# item_name             object
# choice_description    object
# item_price            object
# dtype: object

# %%
df1=pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/beer.txt',sep=" ")
df1.head()
# Out:
#           name  calories  sodium  alcohol  cost
# 0    Budweiser       144      15      4.7  0.43
# 1      Schlitz       151      19      4.9  0.43
# 2    Lowenbrau       157      15      0.9  0.48
# 3  Kronenbourg       170       7      5.2  0.73
# 4     Heineken       152      11      5.0  0.77

# %%
pd.read_csv('https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/04_Apply/US_Crime_Rates/US_Crime_Rates_1960_2014.csv')
# Out:
#     Year  Population     Total  Violent  Property  Murder  Forcible_Rape  \
# 0   1960   179323175   3384200   288460   3095700    9110          17190
# 1   1961   182992000   3488000   289390   3198600    8740          17220
# 2   1962   185771000   3752200   301510   3450700    8530          17550
# 3   1963   188483000   4109500   316970   3792500    8640          17650
# 4   1964   191141000   4564600   364220   4200400    9360          21420
# 5   1965   193526000   4739400   387390   4352000    9960          23410
# 6   1966   195576000   5223500   430180   4793300   11040          25820
# 7   1967   197457000   5903400   499930   5403500   12240          27620
# 8   1968   199399000   6720200   595010   6125200   13800          31670
# 9   1969   201385000   7410900   661870   6749000   14760          37170
# 10  1970   203235298   8098000   738820   7359200   16000          37990
# 11  1971   206212000   8588200   816500   7771700   17780          42260
# ...

# %%
pd.read_csv('https://raw.githubusercontent.com/vincentarelbundock/Rdatasets/master/datasets.csv')
# Out:
#          Package           Item  \
# 0            AER        Affairs
# 1            AER   ArgentinaCPI
# 2            AER      BankWages
# 3            AER  BenderlyZwick
# 4            AER      BondYield
# ...          ...            ...
# 1879  wooldridge          wage1
# 1880  wooldridge          wage2
# 1881  wooldridge        wagepan
# 1882  wooldridge        wageprc
# 1883  wooldridge           wine
#
#                                                   Title  Rows  Cols  n_binary  \
# 0                      Fair's Extramarital Affairs Data   601     9         2
# 1                     Consumer Price Index in Argentina    80     2         0
# 2                                            Bank Wages   474     4         2
# 3     Benderly and Zwick Data: Inflation, Growth and...    31     5         0
# 4                                       Bond Yield Data    60     2         0
# ...                                                 ...   ...   ...       ...
# ...
